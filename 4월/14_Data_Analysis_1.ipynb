# %%
import warnings
warnings.filterwarnings('ignore')
from IPython.display import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = 'NanumGothicCoding'
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False
import seaborn as sns
# %matplotlib inline

# %%
# !pip install plotnine  # 시각화 라이브러리 => R에서 시각화 하는 방법과 유사하게 시각화 한다.
# !pip install missingno # 누락값, 결측치를 그래프로 보여주는 라이브러리
from plotnine import *
import missingno as msno

# %%
# 전국 신규 민간 아파트 분양 가격 동향
# 2015년 10월부터 2018년 7월까지 주택분양 보증을 받아 분양한 전체 민간 신규 아파트 분양가격 동향
# 데이터 다운로드 => https://www.data.go.kr/dataset/3035522/fileData.do

# %%
# 현재 소스 프로그램의 위치(경로)를 보여준다.
# %pwd
# Out:
# 'C:\\Users\\IBK\\Documents\\kyx\\academy'

# %%
# 현재 소스 프로그램의 위치에 저장된 파일 목록을 보여준다.
# %ls # 현재 폴더 아래 폴더의 내용을 보고 싶으면 'ls 폴더이름'으로 실행한다.
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 08F2-C248
#
#  C:\Users\IBK\Documents\kyx\academy 디렉터리
#
#
#  C:\Users\IBK\Documents\kyx\academy 디렉터리
#
#
#  C:\Users\IBK\Documents\kyx\academy 디렉터리
#
#
#  C:\Users\IBK\Documents\kyx\academy 디렉터리
#
#
#  C:\Users\IBK\Documents\kyx\academy 디렉터리
#
#
#  C:\Users\IBK\Documents\kyx\academy 디렉터리
#
#
#  C:\Users\IBK\Documents\kyx\academy 디렉터리
#
#
#  C:\Users\IBK\Documents\kyx\academy 디렉터리
#
#
#  C:\Users\IBK\Documents\kyx\academy 디렉터리
#
#
#  C:\Users\IBK\Documents\kyx\academy 디렉터리
#
#
#  C:\Users\IBK\Documents\kyx\academy 디렉터리
# 파일을 찾을 수 없습니다.

# %%
# read_csv() 메소드로 읽을 csv 파일의 이름이 한글인 경우 파일을 한글 인코딩 문제로 파일을 읽지 못하는 경우가 발생될 수 있다.
pre_sale = pd.read_csv('./data/전국_평균_분양가격_2018.6월_.csv') # 에러가 발생된다면 아래와 같이 한다.
# pre_sale = pd.read_csv('./data/전국_평균_분양가격_2018.6월_.csv', encoding='euc-kr', engine='python')
# pre_sale = pd.read_csv('./data/preSale_2018_6.csv')
pre_sale.shape
# Out:
# (2805, 5)

# %%
pre_sale.head()
# Out:
#   지역명               규모구분    연도   월 분양가격(㎡)
# 0  서울                 전체  2015  10    5841
# 1  서울         전용면적 60㎡이하  2015  10    5652
# 2  서울   전용면적 60㎡초과 85㎡이하  2015  10    5882
# 3  서울  전용면적 85㎡초과 102㎡이하  2015  10    5721
# 4  서울        전용면적 102㎡초과  2015  10    5879

# %%
pre_sale.tail()
# Out:
#      지역명               규모구분    연도  월 분양가격(㎡)
# 2800  제주                 전체  2018  6    3925
# 2801  제주         전용면적 60㎡이하  2018  6    5462
# 2802  제주   전용면적 60㎡초과 85㎡이하  2018  6    3639
# 2803  제주  전용면적 85㎡초과 102㎡이하  2018  6     NaN
# 2804  제주        전용면적 102㎡초과  2018  6    3029

# %%
# info() 메소드나 dtypes 속성을 이용해서 데이터프레임을 구성하는 데이터의 타입을 확인하고 필요하면 변경한다.

# %%
pre_sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2805 entries, 0 to 2804
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      2805 non-null   object
#  1   규모구분     2805 non-null   object
#  2   연도       2805 non-null   int64
#  3   월        2805 non-null   int64
#  4   분양가격(㎡)  2674 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 109.7+ KB

# %%
pre_sale.dtypes
# Out:
# 지역명        object
# 규모구분       object
# 연도          int64
# 월           int64
# 분양가격(㎡)    object
# dtype: object

# %%
# 연도와 열은 연산에 사용되는 데이터가 아니라 구분에 사용되는 카테고리 형태의 데이터이므로 문자열 형태로 변환한다.
pre_sale['연도'] = pre_sale['연도'].astype(str)
pre_sale['월'] = pre_sale['월'].astype(str)

# %%
pre_sale.dtypes
# Out:
# 지역명        object
# 규모구분       object
# 연도         object
# 월          object
# 분양가격(㎡)    object
# dtype: object

# %%
# 분양 가격의 데이터 타입을 숫자로 변경하고 평당 분양 가격을 계산한다.
# pre_sale['분양가격(㎡)'] = pre_sale['분양가격(㎡)'].astype(float)
# to_numeric() 메소드의 errors 속성을 'coerce'로 지정하면 오류가 발생된 데이터를 누락값으로 변경한다.
pre_sale['분양가격(㎡)'] = pd.to_numeric(pre_sale['분양가격(㎡)'], errors='coerce')
pre_sale['평당분양가격'] = pre_sale['분양가격(㎡)'] * 3.3
pre_sale.dtypes
# Out:
# 지역명         object
# 규모구분        object
# 연도          object
# 월           object
# 분양가격(㎡)    float64
# 평당분양가격     float64
# dtype: object

# %%
pre_sale.head()
# Out:
#   지역명               규모구분    연도   월  분양가격(㎡)   평당분양가격
# 0  서울                 전체  2015  10  5,841.0 19,275.3
# 1  서울         전용면적 60㎡이하  2015  10  5,652.0 18,651.6
# 2  서울   전용면적 60㎡초과 85㎡이하  2015  10  5,882.0 19,410.6
# 3  서울  전용면적 85㎡초과 102㎡이하  2015  10  5,721.0 18,879.3
# 4  서울        전용면적 102㎡초과  2015  10  5,879.0 19,400.7

# %%
# isnull() 메소드와 sum() 메소드를 사용해서 누락값이 존재하는가 확인하기
print(pre_sale.isnull().sum())
# Out:
# 지역명          0
# 규모구분         0
# 연도           0
# 월            0
# 분양가격(㎡)    223
# 평당분양가격     223
# dtype: int64

# %%
# missingno 라이브러리로 그래프를 그려서 누락값 확인하기 => 중간 중간에 흰색으로 보이는 부분이 누락값을 의미한다.
msno.matrix(pre_sale, figsize=(10, 6))
plt.show()

# %%
# 2017년 데이터만 추출한다.
# pre_sale_2017 = pre_sale[pre_sale['연도'] == '2017']
pre_sale_2017 = pre_sale.loc[pre_sale['연도'] == '2017']
pre_sale_2017
# Out:
#      지역명               규모구분    연도   월  분양가격(㎡)   평당분양가격
# 1275  서울                 전체  2017   1  6,450.0 21,285.0
# 1276  서울         전용면적 60㎡이하  2017   1  6,662.0 21,984.6
# 1277  서울   전용면적 60㎡초과 85㎡이하  2017   1  6,500.0 21,450.0
# 1278  서울  전용면적 85㎡초과 102㎡이하  2017   1  7,030.0 23,199.0
# 1279  서울        전용면적 102㎡초과  2017   1  6,771.0 22,344.3
# ...   ..                ...   ...  ..      ...      ...
# 2290  제주                 전체  2017  12  3,578.0 11,807.4
# 2291  제주         전용면적 60㎡이하  2017  12  5,380.0 17,754.0
# 2292  제주   전용면적 60㎡초과 85㎡이하  2017  12  3,467.0 11,441.1
# 2293  제주  전용면적 85㎡초과 102㎡이하  2017  12      NaN      NaN
# 2294  제주        전용면적 102㎡초과  2017  12  3,029.0  9,995.7
#
# [1020 rows x 6 columns]

# %%
pre_sale['지역명'].value_counts()
# 시도별 데이터가 동일하게 저장되어 있다.
# Out:
# 세종    165
# 충남    165
# 대구    165
# 전북    165
# 제주    165
# 부산    165
# 서울    165
# 충북    165
# 인천    165
# 울산    165
# 전남    165
# 경남    165
# 경북    165
# 광주    165
# 강원    165
# 대전    165
# 경기    165
# Name: 지역명, dtype: int64

# %%
pre_sale['규모구분'].value_counts()
# 규모구분별 데이터가 동일하게 저장되어 있다.
# Out:
# 전체                   561
# 전용면적 60㎡초과 85㎡이하     561
# 전용면적 60㎡이하           561
# 전용면적 85㎡초과 102㎡이하    561
# 전용면적 102㎡초과          561
# Name: 규모구분, dtype: int64

# %% [markdown]
# 전국 평균 분양 가격

# %%
# pd.options.display.float_format을 사용해서 데이터프레임에 저장된 실수 데이터의 출력 서식을 지정할 수 있다.
# 출력 서식 '{:,.1f}'는 천 단위마다 ','를 출력하고 '.' 뒤의 숫자만큼 소수점 아래로 표현한다.
# 'f'를 붙이지 않으면 실수가 지수 형태로 표시된다.
pd.options.display.float_format = '{:,.1f}'.format

# %%
# groupby() 메소드와 피벗 테이블(T 옵션) 활용하기
# describe() 메소드로 데이터프레임에 저장된 숫자 데이터의 요약 통계량을 확인할 수 있다.
pre_sale.groupby(pre_sale['연도']).describe()
# Out:
#      분양가격(㎡)                                                         평당분양가격  \
#        count    mean     std     min     25%     50%     75%     max  count
# 연도
# 2015   243.0 2,788.7   976.9 1,868.0 2,225.0 2,516.0 3,025.5 7,092.0  243.0
# 2016   984.0 2,934.2 1,071.4 1,900.0 2,282.0 2,672.0 3,148.5 8,096.0  984.0
# 2017   899.0 3,139.5 1,107.6 1,976.0 2,365.0 2,849.0 3,456.0 7,887.0  899.0
# 2018   456.0 3,299.4 1,199.3 2,076.0 2,470.5 2,912.5 3,647.2 8,098.0  456.0
#
#
#          mean     std     min     25%     50%      75%      max
# 연도
# 2015  9,202.7 3,223.6 6,164.4 7,342.5 8,302.8  9,984.1 23,403.6
# 2016  9,683.0 3,535.8 6,270.0 7,530.6 8,817.6 10,390.0 26,716.8
# 2017 10,360.5 3,655.0 6,520.8 7,804.5 9,401.7 11,404.8 26,027.1
# 2018 10,888.1 3,957.7 6,850.8 8,152.6 9,611.2 12,035.9 26,723.4

# %%
# describe() 메소드 실행 결과에 'T'속성을 지정하면 요약 통계량이 수직 방향으로 출력된다.
pre_sale.groupby(pre_sale['연도']).describe().T
# Out:
# 연도                2015     2016     2017     2018
# 분양가격(㎡) count    243.0    984.0    899.0    456.0
#         mean   2,788.7  2,934.2  3,139.5  3,299.4
#         std      976.9  1,071.4  1,107.6  1,199.3
#         min    1,868.0  1,900.0  1,976.0  2,076.0
#         25%    2,225.0  2,282.0  2,365.0  2,470.5
#         50%    2,516.0  2,672.0  2,849.0  2,912.5
#         75%    3,025.5  3,148.5  3,456.0  3,647.2
#         max    7,092.0  8,096.0  7,887.0  8,098.0
# 평당분양가격  count    243.0    984.0    899.0    456.0
#         mean   9,202.7  9,683.0 10,360.5 10,888.1
#         std    3,223.6  3,535.8  3,655.0  3,957.7
#         min    6,164.4  6,270.0  6,520.8  6,850.8
#         25%    7,342.5  7,530.6  7,804.5  8,152.6
#         50%    8,302.8  8,817.6  9,401.7  9,611.2
#         75%    9,984.1 10,390.0 11,404.8 12,035.9
#         max   23,403.6 26,716.8 26,027.1 26,723.4

# %%
# 데이터프레임의 특정 열을 지정할 때 데이터프레임['열이름'] 형태로 사용하는 방식과 데이터프레임.열이름 형태로 사용하는
# 방식은 같은 기능이 실행된다.
pre_sale.groupby(pre_sale.연도).describe().T
# Out:
# 연도                2015     2016     2017     2018
# 분양가격(㎡) count    243.0    984.0    899.0    456.0
#         mean   2,788.7  2,934.2  3,139.5  3,299.4
#         std      976.9  1,071.4  1,107.6  1,199.3
#         min    1,868.0  1,900.0  1,976.0  2,076.0
#         25%    2,225.0  2,282.0  2,365.0  2,470.5
#         50%    2,516.0  2,672.0  2,849.0  2,912.5
#         75%    3,025.5  3,148.5  3,456.0  3,647.2
#         max    7,092.0  8,096.0  7,887.0  8,098.0
# 평당분양가격  count    243.0    984.0    899.0    456.0
#         mean   9,202.7  9,683.0 10,360.5 10,888.1
#         std    3,223.6  3,535.8  3,655.0  3,957.7
#         min    6,164.4  6,270.0  6,520.8  6,850.8
#         25%    7,342.5  7,530.6  7,804.5  8,152.6
#         50%    8,302.8  8,817.6  9,401.7  9,611.2
#         75%    9,984.1 10,390.0 11,404.8 12,035.9
#         max   23,403.6 26,716.8 26,027.1 26,723.4

# %% [markdown]
# 전국 규모별 평균 분양 가격

# %%
# pivot_table(values, index, columns[, aggfunc, fill_value]) => aggfunc, fill_values는 생략 가능하다.
# values     => 통계 함수를 적용할 데이터프레임의 열을 지정한다.
# index      => 그룹화의 첫 번째 기준으로 사욛되는 피벗 테이블로 가져올 데이터프레임의 열을 지정한다.
# columns    => 그룹화의 두 번째 기준으로 사용되는 피벗 테이블로 가져올 데이터프레임의 열을 지정한다.
# aggfunc    => index와 columns로 그룹화된 value에 적용할 함수를 지정한다. => 기본값은 평균을 계산하는 함수 mean 이다.
# fill_value => NaN을 대체할 데이터를 지정한다. => 0을 주로 사용한다.
pre_sale.pivot_table('평당분양가격', '규모구분', '연도')
# Out:
# 연도                   2015     2016     2017     2018
# 규모구분
# 전용면적 102㎡초과       9,837.2 10,388.7 11,334.5 11,259.8
# 전용면적 60㎡이하        8,951.5  9,398.9 10,246.1 10,957.3
# 전용면적 60㎡초과 85㎡이하  8,891.8  9,296.0  9,825.0 10,438.1
# 전용면적 85㎡초과 102㎡이하 9,518.5 10,122.4 10,540.4 11,456.8
# 전체                8,893.0  9,293.0  9,901.3 10,560.3

# %% [markdown]
# 전국 지역별 평균 분양 가격

# %%
# 규모 구분이 전체로 되어있는 금액으로 연도별 변동 금액을 살펴보자
# 규모 구분이 전체인 데이터만 추출한다.
region_year_all = pre_sale[pre_sale['규모구분'] == '전체']
region_year_all
# Out:
#      지역명 규모구분    연도   월  분양가격(㎡)   평당분양가격
# 0     서울   전체  2015  10  5,841.0 19,275.3
# 5     인천   전체  2015  10  3,163.0 10,437.9
# 10    경기   전체  2015  10  3,138.0 10,355.4
# 15    부산   전체  2015  10  3,112.0 10,269.6
# 20    대구   전체  2015  10  2,682.0  8,850.6
# ...   ..  ...   ...  ..      ...      ...
# 2780  전북   전체  2018   6  2,326.0  7,675.8
# 2785  전남   전체  2018   6  2,356.0  7,774.8
# 2790  경북   전체  2018   6  2,631.0  8,682.3
# 2795  경남   전체  2018   6  2,695.0  8,893.5
# 2800  제주   전체  2018   6  3,925.0 12,952.5
#
# [561 rows x 6 columns]

# %%
# 피벗 테이블 결과는 2번째 인수(index)가 피벗 테이블의 index로 사용되므로 index를 다시 지정하려면 reset_index() 메소드를
# 사용해서 다시 붙여주면 된다.
region_year = region_year_all.pivot_table('평당분양가격', '지역명', '연도').reset_index()
region_year
# Out:
# 연도 지역명     2015     2016     2017     2018
# 0   강원  7,159.9  7,011.1  7,126.8  7,642.8
# 1   경기 10,377.4 11,220.0 11,850.0 12,854.0
# 2   경남  7,585.6  7,847.9  8,119.8  8,894.0
# 3   경북  7,170.9  7,360.7  7,794.9  8,261.6
# 4   광주  8,052.0  8,898.7  9,463.5  9,629.9
# 5   대구  9,232.3 10,310.0 11,455.8 11,651.7
# 6   대전  8,098.2  8,501.6  9,044.7  9,588.7
# 7   부산 10,307.0 10,429.9 11,577.9 12,709.9
# 8   서울 19,725.2 20,663.5 21,375.9 22,299.2
# 9   세종  8,750.5  8,860.5  9,135.3 10,381.8
# 10  울산 10,052.9 10,208.6 11,345.1 10,440.6
# 11  인천 10,484.1 10,532.5 10,736.7 11,218.4
# 12  전남  6,317.3  6,488.6  7,187.7  7,794.1
# 13  전북  6,703.4  6,417.9  7,057.8  7,552.1
# 14  제주  7,405.2  9,129.2 10,830.9 12,740.8
# 15  충남  7,114.8  7,330.7  7,456.2  7,972.8
# 16  충북  6,645.1  6,770.2  6,762.6  7,893.1

# %% [markdown]
# 전국 지역별 평균 분양 가격 변동 금액

# %%
region_year['변동액'] = region_year['2018'] - region_year['2015']
region_year
# Out:
# 연도 지역명     2015     2016     2017     2018     변동액
# 0   강원  7,159.9  7,011.1  7,126.8  7,642.8   482.9
# 1   경기 10,377.4 11,220.0 11,850.0 12,854.0 2,476.6
# 2   경남  7,585.6  7,847.9  8,119.8  8,894.0 1,308.4
# 3   경북  7,170.9  7,360.7  7,794.9  8,261.6 1,090.7
# 4   광주  8,052.0  8,898.7  9,463.5  9,629.9 1,577.9
# 5   대구  9,232.3 10,310.0 11,455.8 11,651.7 2,419.4
# 6   대전  8,098.2  8,501.6  9,044.7  9,588.7 1,490.5
# 7   부산 10,307.0 10,429.9 11,577.9 12,709.9 2,403.0
# 8   서울 19,725.2 20,663.5 21,375.9 22,299.2 2,574.0
# 9   세종  8,750.5  8,860.5  9,135.3 10,381.8 1,631.3
# 10  울산 10,052.9 10,208.6 11,345.1 10,440.6   387.7
# 11  인천 10,484.1 10,532.5 10,736.7 11,218.4   734.3
# 12  전남  6,317.3  6,488.6  7,187.7  7,794.1 1,476.8
# 13  전북  6,703.4  6,417.9  7,057.8  7,552.1   848.7
# 14  제주  7,405.2  9,129.2 10,830.9 12,740.8 5,335.6
# 15  충남  7,114.8  7,330.7  7,456.2  7,972.8   858.0
# 16  충북  6,645.1  6,770.2  6,762.6  7,893.1 1,248.0

# %%
max_delta_price = np.max(region_year['변동액']) * 1000
# max_delta_price
print('2015년부터 2018년까지 분양가는 계속 상승했으며, 상승액이 가장 큰 지역은 제주로 상승액은 평당 {0:,.0f}원 이다.'.\
     format(max_delta_price))
# Out:
# 2015년부터 2018년까지 분양가는 계속 상승했으며, 상승액이 가장 큰 지역은 제주로 상승액은 평당 5,335,550원 이다.

# %%
min_delta_price = np.min(region_year['변동액']) * 1000
min_delta_price
# Out:
# 387749.9999999982

# %%
mean_delta_price = np.mean(region_year['변동액']) * 1000
mean_delta_price
# Out:
# 1667276.470588235

# %% [markdown]
# plotnine 패키지를 사용한 시각화

# %%
ggplot(region_year_all, aes(x='지역명', y='평당분양가격', fill='연도')) \
    + geom_bar(stat='identity', position='dodge') \
    + ggtitle('2015 ~ 2018년 신규 민간 아파트 분양가격') \
    + theme(text = element_text(family='NanumGothicCoding'), figure_size=(10, 6))
# Out:
# <ggplot: (-9223371932685612516)>

# %%
# 규모별 지역별 평당 분양가격 합계
pre_sale.pivot_table('평당분양가격', '규모구분', '지역명', sum)
# 아래 피벗 테이블의 데이터로 어느정도 규모로 분양 사업이 이루어졌는지 보자
# 전체 데이터로 봤을 때 서울, 경기, 부산, 제주의 분양 사업이 다른 지역에 비해 규모가 큰 것으로 보여지지만 분양가격 대비로
# 나눠 볼 필요가 있다.
# Out:
# 지역명                      강원        경기        경남        경북        광주        대구  \
# 규모구분
# 전용면적 102㎡초과       251,862.6 435,246.9 295,092.6 274,744.8 269,910.3 393,699.9
# 전용면적 60㎡이하        229,911.0 393,587.7 266,250.6 244,675.2 229,336.8 360,112.5
# 전용면적 60㎡초과 85㎡이하  230,914.2 372,794.4 258,815.7 245,028.3 293,092.8 348,450.3
# 전용면적 85㎡초과 102㎡이하 182,688.0 384,918.6 314,694.6 219,407.1 176,625.9 227,924.4
# 전체                229,864.8 373,246.5 259,614.3 245,153.7 292,818.9 347,341.5
#
# 지역명                      대전        부산        서울        세종        울산        인천  \
# 규모구분
# 전용면적 102㎡초과       171,388.8 402,675.9 705,104.4 296,280.6 249,361.2 428,904.3
# 전용면적 60㎡이하        282,097.2 341,002.2 703,220.1 253,984.5 224,119.5 347,298.6
# 전용면적 60㎡초과 85㎡이하  280,919.1 356,330.7 662,966.7 295,584.3 340,827.3 342,998.7
# 전용면적 85㎡초과 102㎡이하 234,973.2 351,063.9 758,844.9 294,726.3 115,193.1 361,142.1
# 전체                283,338.0 359,696.7 676,067.7 295,356.6 340,101.3 343,256.1
#
# ...

# %%
# 규모별
ggplot(pre_sale, aes(x='지역명', y='평당분양가격', fill='규모구분')) \
    + geom_bar(stat='identity', position='dodge') \
    + ggtitle('규모별 신규 민간 아파트 분양가격') \
    + theme(text = element_text(family='NanumGothicCoding'), figure_size=(10, 6))
# Out:
# <ggplot: (-9223371932685612336)>

# %%
# 위의 그래프를 지역별로 나눠보자
ggplot(pre_sale, aes(x='연도', y='평당분양가격', fill='규모구분')) \
    + geom_bar(stat='identity', position='dodge') \
    + facet_wrap('지역명') \
    + ggtitle('규모별 신규 민간 아파트 분양가격') \
    + theme(text = element_text(family='NanumGothicCoding'), figure_size=(14, 12), axis_text_x=element_text(rotation=90))
# Out:
# <ggplot: (-9223371932685450716)>

# %%
# boxplot을 그려보자
ggplot(pre_sale, aes(x='지역명', y='평당분양가격', fill='규모구분')) \
    + geom_boxplot() \
    + ggtitle('규모별 신규 민간 아파트 분양가격') \
    + theme(text = element_text(family='NanumGothicCoding'), figure_size=(10, 6))
# Out:
# <ggplot: (-9223371932686080188)>

# %%
# 사업 규모가 가장 컸던 서울
pre_sale_seoul = pre_sale[pre_sale['지역명'] == '서울']
pre_sale_seoul
# Out:
#      지역명               규모구분    연도   월  분양가격(㎡)   평당분양가격
# 0     서울                 전체  2015  10  5,841.0 19,275.3
# 1     서울         전용면적 60㎡이하  2015  10  5,652.0 18,651.6
# 2     서울   전용면적 60㎡초과 85㎡이하  2015  10  5,882.0 19,410.6
# 3     서울  전용면적 85㎡초과 102㎡이하  2015  10  5,721.0 18,879.3
# 4     서울        전용면적 102㎡초과  2015  10  5,879.0 19,400.7
# ...   ..                ...   ...  ..      ...      ...
# 2720  서울                 전체  2018   6  6,694.0 22,090.2
# 2721  서울         전용면적 60㎡이하  2018   6  7,232.0 23,865.6
# 2722  서울   전용면적 60㎡초과 85㎡이하  2018   6  6,739.0 22,238.7
# 2723  서울  전용면적 85㎡초과 102㎡이하  2018   6  7,591.0 25,050.3
# 2724  서울        전용면적 102㎡초과  2018   6  6,905.0 22,786.5
#
# [165 rows x 6 columns]

# %%
ggplot(pre_sale_seoul, aes(x='연도', y='평당분양가격', fill='규모구분')) \
    + geom_boxplot() \
    + ggtitle('서울 연도/규모별 신규 민간 아파트 분양가격') \
    + theme(text = element_text(family='NanumGothicCoding'), figure_size=(10, 6))
# Out:
# <ggplot: (-9223371932685765264)>

# %%
# 분양가 차이가 가장 컸던 제주
pre_sale_jeju = pre_sale[pre_sale['지역명'] == '제주']
pre_sale_jeju
# Out:
#      지역명               규모구분    연도   월  분양가격(㎡)   평당분양가격
# 80    제주                 전체  2015  10  2,232.0  7,365.6
# 81    제주         전용면적 60㎡이하  2015  10      NaN      NaN
# 82    제주   전용면적 60㎡초과 85㎡이하  2015  10  2,225.0  7,342.5
# 83    제주  전용면적 85㎡초과 102㎡이하  2015  10  2,583.0  8,523.9
# 84    제주        전용면적 102㎡초과  2015  10  2,574.0  8,494.2
# ...   ..                ...   ...  ..      ...      ...
# 2800  제주                 전체  2018   6  3,925.0 12,952.5
# 2801  제주         전용면적 60㎡이하  2018   6  5,462.0 18,024.6
# 2802  제주   전용면적 60㎡초과 85㎡이하  2018   6  3,639.0 12,008.7
# 2803  제주  전용면적 85㎡초과 102㎡이하  2018   6      NaN      NaN
# 2804  제주        전용면적 102㎡초과  2018   6  3,029.0  9,995.7
#
# [165 rows x 6 columns]

# %%
ggplot(pre_sale_jeju, aes(x='연도', y='평당분양가격', fill='규모구분')) \
    + geom_boxplot() \
    + ggtitle('제주 연도/규모별 신규 민간 아파트 분양가격') \
    + theme(text = element_text(family='NanumGothicCoding'), figure_size=(10, 6))
# Out:
# <ggplot: (-9223371932685758804)>

# %%
# 분양가 차이가 가장 적었던 울산
pre_sale_ulsan = pre_sale[pre_sale['지역명'] == '울산']
pre_sale_ulsan
# Out:
#      지역명               규모구분    연도   월  분양가격(㎡)   평당분양가격
# 35    울산                 전체  2015  10  3,053.0 10,074.9
# 36    울산         전용면적 60㎡이하  2015  10  2,422.0  7,992.6
# 37    울산   전용면적 60㎡초과 85㎡이하  2015  10  3,040.0 10,032.0
# 38    울산  전용면적 85㎡초과 102㎡이하  2015  10  2,951.0  9,738.3
# 39    울산        전용면적 102㎡초과  2015  10  2,690.0  8,877.0
# ...   ..                ...   ...  ..      ...      ...
# 2755  울산                 전체  2018   6  3,125.0 10,312.5
# 2756  울산         전용면적 60㎡이하  2018   6      NaN      NaN
# 2757  울산   전용면적 60㎡초과 85㎡이하  2018   6  3,125.0 10,312.5
# 2758  울산  전용면적 85㎡초과 102㎡이하  2018   6      NaN      NaN
# 2759  울산        전용면적 102㎡초과  2018   6      NaN      NaN
#
# [165 rows x 6 columns]

# %%
ggplot(pre_sale_ulsan, aes(x='연도', y='평당분양가격', fill='규모구분')) \
    + geom_boxplot() \
    + ggtitle('울산 연도/규모별 신규 민간 아파트 분양가격') \
    + theme(text = element_text(family='NanumGothicCoding'), figure_size=(10, 6))
# Out:
# <ggplot: (-9223371932684416448)>
